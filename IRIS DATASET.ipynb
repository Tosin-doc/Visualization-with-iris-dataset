# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
iris = pd.read_csv('iris.csv')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.scatter(iris['sepal_length'],iris['sepal_width'],label='sepal')

# %%
fig,ax = plt.subplots()

ax.scatter(iris['sepal_length'],iris['sepal_width'],label='sepal')
ax.scatter(iris['petal_length'],iris['petal_width'],label='petal')
ax.set_title('iris dataset')
ax.set_xlabel('length')
ax.set_ylabel('width')
# Out:
# Text(0, 0.5, 'width')

# %%
fig,ax = plt.subplots()

ax.scatter(iris['sepal_length'],iris['sepal_width'],label='sepal')
ax.scatter(iris['petal_length'],iris['petal_width'],label='petal')
ax.set_title('iris dataset')
ax.set_xlabel('length')
ax.set_ylabel('width')
ax.legend()

# %%
fig,ax = plt.subplots()
ax.plot(iris.petal_length,label='petal_length')
ax.set_title('petal_length')
ax.legend()

# %%
fig,ax = plt.subplots()
ax.plot(iris.petal_length,iris.petal_width,label='petal_length')
ax.set_title('petal_length')
ax.legend()

# %%
iris.plot.scatter(x='sepal_length',y='sepal_width',title='iris dataset')

# %%
iris.plot.line(title='iris dataset')

# %%
iris_df = iris['sepal_length'].value_counts().sort_index()
iris_df.plot.bar()

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=iris,hue='sepal_length')

# %%
sns.kdeplot(data=iris.drop('species',axis=1))
# Out:
# C:\Users\USER\Documents\APP\lib\site-packages\seaborn\distributions.py:693: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
sns.lineplot(data=iris.drop('species',axis=1))

# %%
sns.countplot(x='sepal_length',data=iris)

# %%
sns.countplot(y='sepal_length',data=iris)

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

iris_new = iris.copy()

iris_new['species'] = le.fit_transform(iris_new['species'])
iris_new['species'].unique()
# Out:
# array([0, 1, 2])

# %%
iris_new.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
x_data = range(0,iris.shape[0])
columns=list(iris_new.columns)

fig,ax = plt.subplots()

#plot each column
for i in columns:
    ax.plot(x_data,iris_new[i],label=i)
#let's make the y axis have no ticks
ax.yaxis.set_ticklabels([])
#let's give y axis a label instead
ax.set_ylabel('Iris columns')

ax.set_title('Iris Dataset')
ax.legend()

# %%
x_data = range(0,iris.shape[0])

iris.shape

iris.shape[0]
# Out:
# 150

# %%
x_data = range(0,iris.shape[0])
columns=list(iris_new.columns)

fig,ax = plt.subplots(figsize=(20,5))

#plot each column
for i in columns:
    ax.plot(x_data,iris_new[i],label=i)
#let's make the y axis have no ticks
ax.yaxis.set_ticklabels([])
#let's give y axis a label instead
ax.set_ylabel('Iris columns')

ax.set_title('Iris Dataset')
ax.legend()
